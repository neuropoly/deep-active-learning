# %%
from __future__ import print_function
from __future__ import division

import json
import os
import matplotlib.pyplot as plt
import numpy as np
import cv2
import gzip
from scipy.misc import imsave
import time
import scipy.ndimage

from keras import backend as K
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D, Dropout

from keras.layers import *
from keras.layers.merge import concatenate
from keras.models import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard
from keras import losses

from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
import cv2
import numpy as np
import gzip
from scipy.misc import imsave
from scipy.ndimage.morphology import distance_transform_edt as edt
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D, Dropout
from keras.layers import *
from keras.layers.merge import concatenate
from keras.models import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import losses
import time
from keras.callbacks import TensorBoard
from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter
from itertools import product
from functools import partial

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
cd ..
# Out:
# /home/malub_local/activelearningADS

# %%
# PATH definition
initial_weights_path = "./models/initial_weights.hdf5"
final_weights_path = "./models/output_weights_batch_norm.hdf5"


# image dimension (array)
img_rows = 512
img_cols = 512

batch_size = 8

# %% [markdown]
# ## Data loading - Data preprocessing

# %%
def preprocessor(input_img, img_rows, img_cols):
    """
    Resize input images to constants sizes
    :param input_img: numpy array of images
    :return: numpy array of preprocessed images
    """
    output_img = np.ndarray((input_img.shape[0], input_img.shape[1], img_rows, img_cols), dtype=np.uint8)
    
    for i in range(input_img.shape[0]):
        output_img[i, 0] = cv2.resize(input_img[i, 0], (img_cols, img_rows), interpolation=cv2.INTER_CUBIC)
    
    return output_img


def load_data(path_img, path_mask, img_rows, img_cols):
    """
    Load data from project path
    :return: [X, y] numpy arrays containing the [training, validation, test] data and their respective masks.
    """
    print("\nLoading data...\n")
    X = np.load(path_img)
    y = np.load(path_mask)

    X = preprocessor(X, img_rows, img_cols)
    y = preprocessor(y, img_rows, img_cols)

    X = X.astype('float32')

    mean = np.mean(X)  # mean for data centering
    std = np.std(X)  # std for data normalization

    X -= mean
    X /= std

    y = y.astype('float32')
    y /= 255.  # scale masks to [0, 1]
    return X, y

# %%
data_path = '../data/'

path_img_train = data_path + 'images_69.npy'
path_mask_train = data_path + 'masks_69.npy'

path_img_valid = data_path + 'images_valid_29.npy'
path_mask_valid = data_path + 'masks_valid_29.npy'

# %%
X_train, y_train = load_data(path_img_train, path_mask_train, img_rows, img_cols )
print("*************Xtrain.shape***********", y_train.shape)


X_valid, y_valid = load_data(path_img_valid, path_mask_valid, img_rows, img_cols)
print("*************Xvalid.shape***********", X_valid.shape)
# Out:
# Loading data...
#
# *************Xtrain.shape*********** (69, 1, 512, 512)
#
# Loading data...
#
# *************Xvalid.shape*********** (29, 1, 512, 512)

# %%
X_valid = X_valid[:-2]
y_valid = y_valid[:-2]

X_test = X_valid[-2:]
y_test = y_valid[-2:]

print(X_valid.shape, y_valid.shape, X_test.shape, y_test.shape)
print(X_test.shape)
# Out:
# (27, 1, 512, 512) (27, 1, 512, 512) (2, 1, 512, 512) (2, 1, 512, 512)
# (2, 1, 512, 512)

# %%
max_images = 60
grid_width = 15
grid_height = int(max_images / grid_width)
fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width, grid_height))
for i in range(max_images):
    img = X_train[i, 0, :, :]
    mask = y_train[i, 0, :, :]
    ax = axs[int(i / grid_width), i % grid_width]
    ax.imshow(img, cmap="gray")
    ax.imshow(mask, alpha=0.3, cmap="gray")
    ax.set_yticklabels([])
    ax.set_xticklabels([])

# %% [markdown]
# ## Build Model

# %% [markdown]
# #### Metrics

# %%
#### loss and metrics #####
def dice_coef(y_true, y_pred, smooth = 1.):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


"""def dice_coef(y_true, y_pred, smooth=1):

    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    return (2. * intersection + smooth) / (K.sum(K.square(y_true),-1) + K.sum(K.square(y_pred),-1) + smooth)"""



def weighted_binary_crossentropy(y_true, y_pred):
        # Calculate the binary crossentropy
    b_ce = K.binary_crossentropy(y_true, y_pred)

        # Apply the weights
    weight_vector = y_true * 0.30 + (1. - y_true) * 0.70
    weighted_b_ce = weight_vector * b_ce

        # Return the mean error
    return K.mean(weighted_b_ce)

# %% [markdown]
# #### Unet

# %%
def unet_full_bn(dropout):
    inputs = Input((1, img_rows, img_cols))
    #conv1 = Convolution2D(32, 3, 3, activation='relu', border_mode='same')(inputs)
    conv1 = Conv2D(32, (3, 3), padding="same", activation="relu")(inputs)
    conv1 = Conv2D(32, (3, 3), padding="same", activation="relu")(conv1)
    batch1 = BatchNormalization(axis=1)(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(batch1)


    conv2 = Conv2D(64, (3, 3), padding="same", activation="relu")(pool1)
    conv2 = Conv2D(64, (3, 3), padding="same", activation="relu")(conv2)
    batch2 = BatchNormalization(axis=1)(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(batch2)

   
    conv3 = Conv2D(128, (3, 3), padding="same", activation="relu")(pool2)
    conv3 = Conv2D(128, (3, 3), padding="same", activation="relu")(conv3)
    batch3 = BatchNormalization(axis=1)(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(batch3)

    conv4 = Conv2D(256, (3, 3), padding="same", activation="relu")(pool3)
    conv4 = Conv2D(256, (3, 3), padding="same", activation="relu")(conv4)
    batch4 = BatchNormalization(axis=1)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(batch4)
    
    if dropout:
        pool4 = Dropout(0.5)(pool4)
   
    conv5 = Conv2D(512, (3, 3), padding="same", activation="relu")(pool4)
    conv5 = Conv2D(512, (3, 3), padding="same", activation="relu")(conv5)

    if dropout:
        conv5 = Dropout(0.5)(conv5)    

    up6_interm = UpSampling2D(size=(2, 2))(conv5)
    
    up6 = concatenate([up6_interm, conv4], axis=1)

    conv6 = Conv2D(256, (3, 3), padding="same", activation="relu")(up6)
    conv6 = Conv2D(256, (3, 3), padding="same", activation="relu")(conv6)
    batch6 = BatchNormalization(axis=1)(conv6)

    up7 = concatenate([UpSampling2D(size=(2, 2))(conv6), conv3], axis=1)
    
    if dropout:
        up7 = Dropout(0.5)(up7)  
        
    conv7 = Conv2D(128, (3, 3), padding="same", activation="relu")(up7)
    conv7 = Conv2D(128, (3, 3), padding="same", activation="relu")(conv7)
    batch7 = BatchNormalization(axis=1)(conv7)

    up8 = concatenate([UpSampling2D(size=(2, 2))(batch7), conv2], axis=1)

    conv8 = Conv2D(64, (3, 3), padding="same", activation="relu")(up8)
    conv8 = Conv2D(64, (3, 3), padding="same", activation="relu")(conv8)
    batch8 = BatchNormalization(axis=1)(conv8)

    up9 = concatenate([UpSampling2D(size=(2, 2))(batch8), conv1], axis=1)

    conv9 = Conv2D(32, (3, 3), padding="same", activation="relu")(up9)
    conv9 = Conv2D(32, (3, 3), padding="same", activation="relu")(conv9)
    batch9 = BatchNormalization(axis=1)(conv9)

    conv10 = Conv2D(1, (1, 1), activation="sigmoid")(batch9)

    #model = Model(input=inputs, output=conv10)
    model = Model(outputs=conv10, inputs=inputs)

    #model.compile(optimizer=Adam(lr=1e-3), loss=dice_coef_loss, metrics=[dice_coef])
    #model.compile(optimizer=Adam(lr=1e-3), loss=losses.binary_crossentropy, metrics = [dice_coef])
    model.compile(optimizer=Adam(lr = learning_rate, decay=decay_rate), loss=weighted_binary_crossentropy, 
                  metrics = [dice_coef])

    return model

# %% [markdown]
# ### Data Augmentation

# %%
### data augmentation ######
def data_generator():
    """
    :return: Keras data generator. Data augmentation parameters.
    """
    return ImageDataGenerator(
        #fill_mode = fill_mode,
        rotation_range = rotation_range,
        horizontal_flip = horizontal_flip,
        vertical_flip = vertical_flip,
        rescale = rescale,
        zoom_range = zoom_range,
        channel_shift_range = channel_shift_range,
        width_shift_range = width_shift_range,
        height_shift_range = height_shift_range)

# %%
#fill_mode = 'reflect'
rotation_range= 5
horizontal_flip= True
vertical_flip = True
rescale = 0
zoom_range= 0
channel_shift_range = 0
width_shift_range = 0
height_shift_range = 0

# %%
# data augmentation
seed = 1

train_img_generator = data_generator().flow(X_train, seed = seed, batch_size = batch_size,  shuffle=False)
train_mask_generator = data_generator().flow(y_train, seed = seed, batch_size = batch_size, shuffle=False)

train_generator = zip(train_img_generator, train_mask_generator)




val_img_generator = data_generator().flow(X_valid, seed = seed, batch_size = batch_size, shuffle=False)
val_mask_generator = data_generator().flow(y_valid, seed = seed, batch_size = batch_size, shuffle=False)

val_generator = zip(val_img_generator, val_mask_generator)


"""train_generator = data_generator().flow(X_train, y_train,
                                      batch_size = batch_size, seed = seed, 
                                      shuffle = False)"""

"""val_generator = data_generator().flow(X_valid, y_valid,
                                      batch_size = batch_size, seed = seed, 
                                      shuffle = False)
"""
# Out:
# 'val_generator = data_generator().flow(X_valid, y_valid,\n                                      batch_size = batch_size, seed = seed, \n                                      shuffle = False)\n'

# %%
max_images = 16
grid_width = 8
grid_height = 1
fig, axs = plt.subplots(grid_height, grid_width, figsize=(20, 10))
for i in range(8):
    img = train_generator[0][0][i, 0, :, :]
    mask = train_generator[0][1][i, 0, :, :]
    ax = axs[ i % grid_width]
    ax.imshow(img, cmap="gray")
    ax.set_yticklabels([])
    ax.set_xticklabels([])


fig, axs = plt.subplots(grid_height, grid_width, figsize=(20, 10))
for i in range(8):
    img = train_generator[0][0][i, 0, :, :]
    mask = train_generator[0][1][i, 0, :, :]
    ax = axs[ i % grid_width]
    ax.imshow(mask, cmap="gray")
    ax.set_yticklabels([])
    ax.set_xticklabels([])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-bc4d3fdd24e6> in <module>()
#       4 fig, axs = plt.subplots(grid_height, grid_width, figsize=(20, 10))
#       5 for i in range(8):
# ----> 6     img = train_generator[0][0][i, 0, :, :]
#       7     mask = train_generator[0][1][i, 0, :, :]
#       8     ax = axs[ i % grid_width]
#
# TypeError: 'itertools.izip' object has no attribute '__getitem__'

# %% [markdown]
# ## Training

# %%
K.set_image_dim_ordering('th')  # Theano dimension ordering in this code
smooth = 1.
Dropout.call = call

nb_initial_epochs = 300
apply_augmentation = True
nb_step_predictions = 20

learning_rate = 1e-3
decay_rate = learning_rate / nb_initial_epochs


apply_edt = False

# %%
#Override Dropout. Make it able at test time.
def call(self, inputs, training=None):
    if 0. < self.rate < 1.:
        noise_shape = self._get_noise_shape(inputs)
        def dropped_inputs():
            return K.dropout(inputs, self.rate, noise_shape,
                             seed=self.seed)
        if (training):
            return K.in_train_phase(dropped_inputs, inputs, training=training)
        else:
            return K.in_test_phase(dropped_inputs, inputs, training=None)
    return inputs

def reset_weights(model):
    session = K.get_session()
    for layer in model.layers: 
        if hasattr(layer, 'kernel_initializer'):
            layer.kernel.initializer.run(session=session)

# %%
model = unet_full_bn(dropout = True)
reset_weights(model)
print(model.summary())

model_checkpoint = ModelCheckpoint(initial_weights_path, monitor='loss', save_best_only = True)


# if Data Augmentation
if apply_augmentation:
    timestamp = format(time.strftime('%m%d_%H%M_%S'))
    tensorboard = TensorBoard(log_dir = str("../logs/" + str(timestamp)))
    history = model.fit_generator(train_generator, 
                                  validation_data = val_generator,
                                  epochs = nb_initial_epochs, 
                                  verbose = 1,
                                  shuffle = True,
                                  steps_per_epoch=20, 
                                  validation_steps= 80,
                                  callbacks = [tensorboard])
    model.save(final_weights_path)

    
# if No Data Augmentation
else:
    timestamp = format(time.strftime('%m%d_%H%M_%S'))
    tensorboard = TensorBoard(log_dir = str("../logs/" + str(timestamp)))
    history = model.fit(X_train, y_train, validation_data = (X_valid, y_valid),
                            batch_size = batch_size, 
                            epochs = nb_initial_epochs,
                            verbose = 1, 
                            shuffle = True, 
                            callbacks = [tensorboard])
    model.save(final_weights_path)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 1, 512, 512)  0
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 32, 512, 512) 320         input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 32, 512, 512) 9248        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 512, 512) 128         conv2d_78[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 32, 256, 256) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 64, 256, 256) 18496       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 64, 256, 256) 36928       conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 64, 256, 256) 256         conv2d_80[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 64, 128, 128) 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 128, 128, 128 73856       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 128, 128, 128 147584      conv2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 128, 128, 128 512         conv2d_82[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 128, 64, 64)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 256, 64, 64)  295168      max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 256, 64, 64)  590080      conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 256, 64, 64)  1024        conv2d_84[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 256, 32, 32)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 256, 32, 32)  0           max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 512, 32, 32)  1180160     dropout_13[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 512, 32, 32)  2359808     conv2d_85[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 512, 32, 32)  0           conv2d_86[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 512, 64, 64)  0           dropout_14[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 768, 64, 64)  0           up_sampling2d_17[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 256, 64, 64)  1769728     concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 256, 64, 64)  590080      conv2d_87[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_18 (UpSampling2D) (None, 256, 128, 128 0           conv2d_88[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 384, 128, 128 0           up_sampling2d_18[0][0]
#                                                                  conv2d_82[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 384, 128, 128 0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 128, 128, 128 442496      dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 128, 128, 128 147584      conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 128, 128, 128 512         conv2d_90[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_19 (UpSampling2D) (None, 128, 256, 256 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 192, 256, 256 0           up_sampling2d_19[0][0]
#                                                                  conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 64, 256, 256) 110656      concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 64, 256, 256) 36928       conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 64, 256, 256) 256         conv2d_92[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_20 (UpSampling2D) (None, 64, 512, 512) 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 96, 512, 512) 0           up_sampling2d_20[0][0]
#                                                                  conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 32, 512, 512) 27680       concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 32, 512, 512) 9248        conv2d_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 512, 512) 128         conv2d_94[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 1, 512, 512)  33          batch_normalization_40[0][0]
# ==================================================================================================
# Total params: 7,848,897
# Trainable params: 7,847,489
# Non-trainable params: 1,408
# __________________________________________________________________________________________________
# None
# Epoch 1/300
# 20/20 [==============================] - 34s 2s/step - loss: 0.3347 - dice_coef: 0.5357 - val_loss: 1.0114 - val_dice_coef: 0.5146
# Epoch 2/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.3046 - dice_coef: 0.5395 - val_loss: 1.1814 - val_dice_coef: 0.0230
# Epoch 3/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2982 - dice_coef: 0.5239 - val_loss: 0.2486 - val_dice_coef: 0.3731
# Epoch 4/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2617 - dice_coef: 0.5513 - val_loss: 0.4981 - val_dice_coef: 0.0557
# Epoch 5/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2530 - dice_coef: 0.5462 - val_loss: 0.2030 - val_dice_coef: 0.4840
# Epoch 6/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.2399 - dice_coef: 0.5508 - val_loss: 0.2206 - val_dice_coef: 0.3411
# Epoch 7/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2496 - dice_coef: 0.5033 - val_loss: 0.2207 - val_dice_coef: 0.4963
# Epoch 8/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2403 - dice_coef: 0.5071 - val_loss: 0.2338 - val_dice_coef: 0.5432
# Epoch 9/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2408 - dice_coef: 0.5064 - val_loss: 0.2003 - val_dice_coef: 0.5401
# Epoch 10/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2349 - dice_coef: 0.4870 - val_loss: 0.2045 - val_dice_coef: 0.4917
# Epoch 11/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2451 - dice_coef: 0.4810 - val_loss: 0.2103 - val_dice_coef: 0.5698
# Epoch 12/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2307 - dice_coef: 0.4770 - val_loss: 0.1916 - val_dice_coef: 0.5328
# Epoch 13/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2250 - dice_coef: 0.5157 - val_loss: 0.1894 - val_dice_coef: 0.5162
# Epoch 14/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2094 - dice_coef: 0.5367 - val_loss: 0.1955 - val_dice_coef: 0.5550
# Epoch 15/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2234 - dice_coef: 0.5334 - val_loss: 0.1870 - val_dice_coef: 0.5173
# Epoch 16/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2322 - dice_coef: 0.4911 - val_loss: 0.2155 - val_dice_coef: 0.5575
# Epoch 17/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2279 - dice_coef: 0.4890 - val_loss: 0.1997 - val_dice_coef: 0.5296
# Epoch 18/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2402 - dice_coef: 0.4774 - val_loss: 0.2193 - val_dice_coef: 0.4886
# Epoch 19/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2177 - dice_coef: 0.4862 - val_loss: 0.1857 - val_dice_coef: 0.5064
# Epoch 20/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2253 - dice_coef: 0.5167 - val_loss: 0.2105 - val_dice_coef: 0.5397
# Epoch 21/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2331 - dice_coef: 0.4974 - val_loss: 0.2079 - val_dice_coef: 0.5436
# Epoch 22/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2261 - dice_coef: 0.4858 - val_loss: 0.1860 - val_dice_coef: 0.4976
# Epoch 23/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2084 - dice_coef: 0.5273 - val_loss: 0.1785 - val_dice_coef: 0.5386
# Epoch 24/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2290 - dice_coef: 0.5207 - val_loss: 0.2170 - val_dice_coef: 0.5395
# Epoch 25/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2313 - dice_coef: 0.4884 - val_loss: 0.2001 - val_dice_coef: 0.4767
# Epoch 26/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.2189 - dice_coef: 0.5020 - val_loss: 0.1899 - val_dice_coef: 0.5086
# Epoch 27/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2319 - dice_coef: 0.4996 - val_loss: 0.1896 - val_dice_coef: 0.5020
# Epoch 28/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2231 - dice_coef: 0.5005 - val_loss: 0.2028 - val_dice_coef: 0.4810
# Epoch 29/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1994 - dice_coef: 0.5411 - val_loss: 0.1801 - val_dice_coef: 0.5014
# Epoch 30/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2327 - dice_coef: 0.5274 - val_loss: 0.2221 - val_dice_coef: 0.5355
# Epoch 31/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2192 - dice_coef: 0.5111 - val_loss: 0.1798 - val_dice_coef: 0.5241
# Epoch 32/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2137 - dice_coef: 0.5220 - val_loss: 0.1921 - val_dice_coef: 0.4463
# Epoch 33/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2158 - dice_coef: 0.5324 - val_loss: 0.1810 - val_dice_coef: 0.5630
# Epoch 34/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2272 - dice_coef: 0.5125 - val_loss: 0.2213 - val_dice_coef: 0.4806
# Epoch 35/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2064 - dice_coef: 0.5312 - val_loss: 0.1823 - val_dice_coef: 0.5433
# Epoch 36/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2173 - dice_coef: 0.5348 - val_loss: 0.1938 - val_dice_coef: 0.5191
# Epoch 37/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2044 - dice_coef: 0.5487 - val_loss: 0.1880 - val_dice_coef: 0.5355
# Epoch 38/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2020 - dice_coef: 0.5635 - val_loss: 0.1907 - val_dice_coef: 0.5273
# Epoch 39/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2165 - dice_coef: 0.5529 - val_loss: 0.2082 - val_dice_coef: 0.5125
# Epoch 40/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2281 - dice_coef: 0.5154 - val_loss: 0.1969 - val_dice_coef: 0.4669
# Epoch 41/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2130 - dice_coef: 0.5252 - val_loss: 0.1962 - val_dice_coef: 0.5432
# Epoch 42/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2238 - dice_coef: 0.5215 - val_loss: 0.2002 - val_dice_coef: 0.5224
# Epoch 43/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2026 - dice_coef: 0.5409 - val_loss: 0.1946 - val_dice_coef: 0.5506
# Epoch 44/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2359 - dice_coef: 0.5125 - val_loss: 0.2134 - val_dice_coef: 0.4052
# Epoch 45/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2444 - dice_coef: 0.4657 - val_loss: 0.2628 - val_dice_coef: 0.3907
# Epoch 46/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2355 - dice_coef: 0.4454 - val_loss: 0.2124 - val_dice_coef: 0.4357
# Epoch 47/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2201 - dice_coef: 0.5127 - val_loss: 0.1865 - val_dice_coef: 0.5066
# Epoch 48/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2155 - dice_coef: 0.5361 - val_loss: 0.1918 - val_dice_coef: 0.4383
# Epoch 49/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2176 - dice_coef: 0.5303 - val_loss: 0.1893 - val_dice_coef: 0.4948
# Epoch 50/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2007 - dice_coef: 0.5504 - val_loss: 0.1820 - val_dice_coef: 0.4741
# Epoch 51/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2230 - dice_coef: 0.5469 - val_loss: 0.1963 - val_dice_coef: 0.4793
# Epoch 52/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2041 - dice_coef: 0.5438 - val_loss: 0.1895 - val_dice_coef: 0.5062
# Epoch 53/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2256 - dice_coef: 0.5331 - val_loss: 0.1986 - val_dice_coef: 0.4744
# Epoch 54/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2183 - dice_coef: 0.5182 - val_loss: 0.1929 - val_dice_coef: 0.5011
# Epoch 55/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2156 - dice_coef: 0.5280 - val_loss: 0.1902 - val_dice_coef: 0.5144
# Epoch 56/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2051 - dice_coef: 0.5457 - val_loss: 0.1802 - val_dice_coef: 0.5100
# Epoch 57/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.2111 - dice_coef: 0.5563 - val_loss: 0.1803 - val_dice_coef: 0.4921
# Epoch 58/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2118 - dice_coef: 0.5511 - val_loss: 0.1898 - val_dice_coef: 0.5207
# Epoch 59/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.1911 - dice_coef: 0.5749 - val_loss: 0.1680 - val_dice_coef: 0.5387
# Epoch 60/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2131 - dice_coef: 0.5647 - val_loss: 0.1951 - val_dice_coef: 0.5279
# Epoch 61/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.2137 - dice_coef: 0.5480 - val_loss: 0.1869 - val_dice_coef: 0.4555
# Epoch 62/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1978 - dice_coef: 0.5627 - val_loss: 0.1748 - val_dice_coef: 0.5236
# Epoch 63/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1984 - dice_coef: 0.5814 - val_loss: 0.1801 - val_dice_coef: 0.5048
# Epoch 64/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2239 - dice_coef: 0.5477 - val_loss: 0.1872 - val_dice_coef: 0.4799
# Epoch 65/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2180 - dice_coef: 0.5303 - val_loss: 0.1843 - val_dice_coef: 0.5083
# Epoch 66/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.1897 - dice_coef: 0.5672 - val_loss: 0.1733 - val_dice_coef: 0.5392
# Epoch 67/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2206 - dice_coef: 0.5544 - val_loss: 0.1807 - val_dice_coef: 0.5009
# Epoch 68/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2104 - dice_coef: 0.5497 - val_loss: 0.1935 - val_dice_coef: 0.5334
# Epoch 69/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1769 - dice_coef: 0.5911 - val_loss: 0.1679 - val_dice_coef: 0.5605
# Epoch 70/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1880 - dice_coef: 0.6097 - val_loss: 0.1731 - val_dice_coef: 0.5853
# Epoch 71/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1944 - dice_coef: 0.6103 - val_loss: 0.1759 - val_dice_coef: 0.5825
# Epoch 72/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2075 - dice_coef: 0.5826 - val_loss: 0.1764 - val_dice_coef: 0.5338
# Epoch 73/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2193 - dice_coef: 0.5503 - val_loss: 0.1976 - val_dice_coef: 0.5005
# Epoch 74/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1921 - dice_coef: 0.5733 - val_loss: 0.1749 - val_dice_coef: 0.5594
# Epoch 75/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2151 - dice_coef: 0.5608 - val_loss: 0.2158 - val_dice_coef: 0.5530
# Epoch 76/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2428 - dice_coef: 0.5018 - val_loss: 0.2004 - val_dice_coef: 0.4264
# Epoch 77/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2097 - dice_coef: 0.5210 - val_loss: 0.1763 - val_dice_coef: 0.5158
# Epoch 78/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2085 - dice_coef: 0.5485 - val_loss: 0.1814 - val_dice_coef: 0.4914
# Epoch 79/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1970 - dice_coef: 0.5736 - val_loss: 0.1760 - val_dice_coef: 0.5641
# Epoch 80/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2063 - dice_coef: 0.5703 - val_loss: 0.1855 - val_dice_coef: 0.4864
# Epoch 81/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2013 - dice_coef: 0.5776 - val_loss: 0.1848 - val_dice_coef: 0.5579
# Epoch 82/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1920 - dice_coef: 0.5855 - val_loss: 0.1761 - val_dice_coef: 0.5362
# Epoch 83/300
# 20/20 [==============================] - 33s 2s/step - loss: 0.1788 - dice_coef: 0.6135 - val_loss: 0.1665 - val_dice_coef: 0.6054
# Epoch 84/300
# 20/20 [==============================] - 34s 2s/step - loss: 0.2039 - dice_coef: 0.6031 - val_loss: 0.1719 - val_dice_coef: 0.5767
# Epoch 85/300
# 20/20 [==============================] - 34s 2s/step - loss: 0.2182 - dice_coef: 0.5611 - val_loss: 0.1777 - val_dice_coef: 0.5259
# Epoch 86/300
# 20/20 [==============================] - 34s 2s/step - loss: 0.1993 - dice_coef: 0.5655 - val_loss: 0.1890 - val_dice_coef: 0.5603
# Epoch 87/300
# 20/20 [==============================] - 34s 2s/step - loss: 0.2102 - dice_coef: 0.5591 - val_loss: 0.1770 - val_dice_coef: 0.5675
# Epoch 88/300
# 20/20 [==============================] - 34s 2s/step - loss: 0.2064 - dice_coef: 0.5615 - val_loss: 0.1810 - val_dice_coef: 0.5472
# Epoch 89/300
# 20/20 [==============================] - 34s 2s/step - loss: 0.2226 - dice_coef: 0.5412 - val_loss: 0.1945 - val_dice_coef: 0.4867
# Epoch 90/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2013 - dice_coef: 0.5540 - val_loss: 0.1915 - val_dice_coef: 0.5574
# Epoch 91/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2188 - dice_coef: 0.5413 - val_loss: 0.1756 - val_dice_coef: 0.5459
# Epoch 92/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2011 - dice_coef: 0.5606 - val_loss: 0.1809 - val_dice_coef: 0.5465
# Epoch 93/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2035 - dice_coef: 0.5692 - val_loss: 0.1756 - val_dice_coef: 0.5427
# Epoch 94/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2033 - dice_coef: 0.5708 - val_loss: 0.1796 - val_dice_coef: 0.5158
# Epoch 95/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2071 - dice_coef: 0.5711 - val_loss: 0.1745 - val_dice_coef: 0.5530
# Epoch 96/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1981 - dice_coef: 0.5752 - val_loss: 0.1781 - val_dice_coef: 0.5298
# Epoch 97/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2022 - dice_coef: 0.5742 - val_loss: 0.1757 - val_dice_coef: 0.5536
# Epoch 98/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1867 - dice_coef: 0.5940 - val_loss: 0.1797 - val_dice_coef: 0.5481
# Epoch 99/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1920 - dice_coef: 0.6011 - val_loss: 0.1789 - val_dice_coef: 0.5622
# Epoch 100/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2013 - dice_coef: 0.5895 - val_loss: 0.1754 - val_dice_coef: 0.5607
# Epoch 101/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2003 - dice_coef: 0.5848 - val_loss: 0.1957 - val_dice_coef: 0.5760
# Epoch 102/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2095 - dice_coef: 0.5700 - val_loss: 0.2007 - val_dice_coef: 0.4155
# Epoch 103/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2028 - dice_coef: 0.5712 - val_loss: 0.1766 - val_dice_coef: 0.5838
# Epoch 104/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1978 - dice_coef: 0.5783 - val_loss: 0.1748 - val_dice_coef: 0.5753
# Epoch 105/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2069 - dice_coef: 0.5738 - val_loss: 0.1771 - val_dice_coef: 0.5618
# Epoch 106/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1974 - dice_coef: 0.5804 - val_loss: 0.1789 - val_dice_coef: 0.5467
# Epoch 107/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2068 - dice_coef: 0.5757 - val_loss: 0.1755 - val_dice_coef: 0.5421
# Epoch 108/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2052 - dice_coef: 0.5687 - val_loss: 0.1758 - val_dice_coef: 0.5289
# Epoch 109/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1999 - dice_coef: 0.5743 - val_loss: 0.1900 - val_dice_coef: 0.5615
# Epoch 110/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2091 - dice_coef: 0.5654 - val_loss: 0.1831 - val_dice_coef: 0.5276
# Epoch 111/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1866 - dice_coef: 0.5900 - val_loss: 0.1782 - val_dice_coef: 0.5365
# Epoch 112/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1984 - dice_coef: 0.5896 - val_loss: 0.1734 - val_dice_coef: 0.5565
# Epoch 113/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1989 - dice_coef: 0.5913 - val_loss: 0.1791 - val_dice_coef: 0.5494
# Epoch 114/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1959 - dice_coef: 0.5906 - val_loss: 0.1775 - val_dice_coef: 0.5470
# Epoch 115/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1813 - dice_coef: 0.6102 - val_loss: 0.1803 - val_dice_coef: 0.5848
# Epoch 116/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2189 - dice_coef: 0.5723 - val_loss: 0.1856 - val_dice_coef: 0.5381
# Epoch 117/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1899 - dice_coef: 0.5891 - val_loss: 0.1837 - val_dice_coef: 0.5412
# Epoch 118/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1837 - dice_coef: 0.6045 - val_loss: 0.1793 - val_dice_coef: 0.5370
# Epoch 119/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1821 - dice_coef: 0.6219 - val_loss: 0.1766 - val_dice_coef: 0.6036
# Epoch 120/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1856 - dice_coef: 0.6248 - val_loss: 0.1843 - val_dice_coef: 0.5983
# Epoch 121/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2041 - dice_coef: 0.6005 - val_loss: 0.1917 - val_dice_coef: 0.5654
# Epoch 122/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1772 - dice_coef: 0.6156 - val_loss: 0.1802 - val_dice_coef: 0.5716
# Epoch 123/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1968 - dice_coef: 0.6071 - val_loss: 0.1764 - val_dice_coef: 0.5908
# Epoch 124/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1646 - dice_coef: 0.6413 - val_loss: 0.1725 - val_dice_coef: 0.5984
# Epoch 125/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2132 - dice_coef: 0.6040 - val_loss: 0.1752 - val_dice_coef: 0.6068
# Epoch 126/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2111 - dice_coef: 0.5691 - val_loss: 0.1827 - val_dice_coef: 0.5399
# Epoch 127/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1967 - dice_coef: 0.5781 - val_loss: 0.1809 - val_dice_coef: 0.5771
# Epoch 128/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2071 - dice_coef: 0.5744 - val_loss: 0.1846 - val_dice_coef: 0.5391
# Epoch 129/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2037 - dice_coef: 0.5746 - val_loss: 0.1810 - val_dice_coef: 0.5690
# Epoch 130/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2001 - dice_coef: 0.5791 - val_loss: 0.1802 - val_dice_coef: 0.5486
# Epoch 131/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1883 - dice_coef: 0.5955 - val_loss: 0.1661 - val_dice_coef: 0.5831
# Epoch 132/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2139 - dice_coef: 0.5741 - val_loss: 0.1879 - val_dice_coef: 0.5808
# Epoch 133/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1806 - dice_coef: 0.6053 - val_loss: 0.1764 - val_dice_coef: 0.5794
# Epoch 134/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2293 - dice_coef: 0.5555 - val_loss: 0.1802 - val_dice_coef: 0.5187
# Epoch 135/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1967 - dice_coef: 0.5741 - val_loss: 0.1872 - val_dice_coef: 0.5113
# Epoch 136/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2070 - dice_coef: 0.5656 - val_loss: 0.1794 - val_dice_coef: 0.5335
# Epoch 137/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2011 - dice_coef: 0.5755 - val_loss: 0.1791 - val_dice_coef: 0.5411
# Epoch 138/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2153 - dice_coef: 0.5579 - val_loss: 0.1871 - val_dice_coef: 0.4951
# Epoch 139/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1801 - dice_coef: 0.5982 - val_loss: 0.1795 - val_dice_coef: 0.5361
# Epoch 140/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1725 - dice_coef: 0.6272 - val_loss: 0.1737 - val_dice_coef: 0.5838
# Epoch 141/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1826 - dice_coef: 0.6286 - val_loss: 0.1767 - val_dice_coef: 0.6003
# Epoch 142/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1834 - dice_coef: 0.6322 - val_loss: 0.1789 - val_dice_coef: 0.5875
# Epoch 143/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1915 - dice_coef: 0.6230 - val_loss: 0.1826 - val_dice_coef: 0.5638
# Epoch 144/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1993 - dice_coef: 0.6001 - val_loss: 0.1801 - val_dice_coef: 0.5708
# Epoch 145/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2133 - dice_coef: 0.5738 - val_loss: 0.1986 - val_dice_coef: 0.5502
# Epoch 146/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1971 - dice_coef: 0.5788 - val_loss: 0.1803 - val_dice_coef: 0.5505
# Epoch 147/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2065 - dice_coef: 0.5739 - val_loss: 0.1887 - val_dice_coef: 0.5784
# Epoch 148/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2193 - dice_coef: 0.5503 - val_loss: 0.1786 - val_dice_coef: 0.5182
# Epoch 149/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1957 - dice_coef: 0.5710 - val_loss: 0.1768 - val_dice_coef: 0.5464
# Epoch 150/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1971 - dice_coef: 0.5843 - val_loss: 0.1827 - val_dice_coef: 0.5420
# Epoch 151/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.1729 - dice_coef: 0.6198 - val_loss: 0.1702 - val_dice_coef: 0.5919
# Epoch 152/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2125 - dice_coef: 0.5866 - val_loss: 0.1851 - val_dice_coef: 0.5716
# Epoch 153/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2074 - dice_coef: 0.5768 - val_loss: 0.1806 - val_dice_coef: 0.5281
# Epoch 154/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2076 - dice_coef: 0.5668 - val_loss: 0.1904 - val_dice_coef: 0.5422
# Epoch 155/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1843 - dice_coef: 0.5960 - val_loss: 0.1811 - val_dice_coef: 0.5791
# Epoch 156/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1792 - dice_coef: 0.6173 - val_loss: 0.1781 - val_dice_coef: 0.5574
# Epoch 157/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1869 - dice_coef: 0.6193 - val_loss: 0.1722 - val_dice_coef: 0.5807
# Epoch 158/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2013 - dice_coef: 0.6021 - val_loss: 0.1815 - val_dice_coef: 0.5510
# Epoch 159/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.1595 - dice_coef: 0.6436 - val_loss: 0.1748 - val_dice_coef: 0.5967
# Epoch 160/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1838 - dice_coef: 0.6384 - val_loss: 0.1784 - val_dice_coef: 0.5624
# Epoch 161/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1869 - dice_coef: 0.6298 - val_loss: 0.1772 - val_dice_coef: 0.5609
# Epoch 162/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1856 - dice_coef: 0.6255 - val_loss: 0.1820 - val_dice_coef: 0.5685
# Epoch 163/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2077 - dice_coef: 0.5965 - val_loss: 0.1857 - val_dice_coef: 0.5600
# Epoch 164/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.1932 - dice_coef: 0.5963 - val_loss: 0.1892 - val_dice_coef: 0.5651
# Epoch 165/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1988 - dice_coef: 0.5963 - val_loss: 0.1762 - val_dice_coef: 0.5383
# Epoch 166/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1877 - dice_coef: 0.6043 - val_loss: 0.1741 - val_dice_coef: 0.5615
# Epoch 167/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1854 - dice_coef: 0.6127 - val_loss: 0.1759 - val_dice_coef: 0.5537
# Epoch 168/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1807 - dice_coef: 0.6241 - val_loss: 0.1765 - val_dice_coef: 0.5737
# Epoch 169/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2001 - dice_coef: 0.6064 - val_loss: 0.1757 - val_dice_coef: 0.5566
# Epoch 170/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1916 - dice_coef: 0.6065 - val_loss: 0.1804 - val_dice_coef: 0.5159
# Epoch 171/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1928 - dice_coef: 0.6062 - val_loss: 0.2011 - val_dice_coef: 0.5724
# Epoch 172/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1666 - dice_coef: 0.6373 - val_loss: 0.1688 - val_dice_coef: 0.5935
# Epoch 173/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1850 - dice_coef: 0.6354 - val_loss: 0.1714 - val_dice_coef: 0.6139
# Epoch 174/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1922 - dice_coef: 0.6238 - val_loss: 0.1805 - val_dice_coef: 0.5778
# Epoch 175/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1828 - dice_coef: 0.6233 - val_loss: 0.1807 - val_dice_coef: 0.5666
# Epoch 176/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1805 - dice_coef: 0.6277 - val_loss: 0.1779 - val_dice_coef: 0.5551
# Epoch 177/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1738 - dice_coef: 0.6414 - val_loss: 0.1814 - val_dice_coef: 0.6004
# Epoch 178/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.1796 - dice_coef: 0.6418 - val_loss: 0.1749 - val_dice_coef: 0.5940
# Epoch 179/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1824 - dice_coef: 0.6379 - val_loss: 0.1803 - val_dice_coef: 0.5887
# Epoch 180/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1980 - dice_coef: 0.6151 - val_loss: 0.1829 - val_dice_coef: 0.5778
# Epoch 181/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1914 - dice_coef: 0.6113 - val_loss: 0.1812 - val_dice_coef: 0.5722
# Epoch 182/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1891 - dice_coef: 0.6101 - val_loss: 0.1778 - val_dice_coef: 0.5626
# Epoch 183/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1985 - dice_coef: 0.6017 - val_loss: 0.1772 - val_dice_coef: 0.5622
# Epoch 184/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1989 - dice_coef: 0.5934 - val_loss: 0.1903 - val_dice_coef: 0.5598
# Epoch 185/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1692 - dice_coef: 0.6299 - val_loss: 0.1783 - val_dice_coef: 0.5757
# Epoch 186/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1982 - dice_coef: 0.6129 - val_loss: 0.1878 - val_dice_coef: 0.5625
# Epoch 187/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1992 - dice_coef: 0.6027 - val_loss: 0.1942 - val_dice_coef: 0.5769
# Epoch 188/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2116 - dice_coef: 0.5756 - val_loss: 0.1855 - val_dice_coef: 0.5508
# Epoch 189/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1961 - dice_coef: 0.5852 - val_loss: 0.1857 - val_dice_coef: 0.5395
# Epoch 190/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1978 - dice_coef: 0.5877 - val_loss: 0.1775 - val_dice_coef: 0.5405
# Epoch 191/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1757 - dice_coef: 0.6190 - val_loss: 0.1735 - val_dice_coef: 0.5898
# Epoch 192/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1843 - dice_coef: 0.6226 - val_loss: 0.1809 - val_dice_coef: 0.5915
# Epoch 193/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1988 - dice_coef: 0.6100 - val_loss: 0.1795 - val_dice_coef: 0.5745
# Epoch 194/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1581 - dice_coef: 0.6492 - val_loss: 0.1722 - val_dice_coef: 0.5904
# Epoch 195/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1432 - dice_coef: 0.6857 - val_loss: 0.1789 - val_dice_coef: 0.6455
# Epoch 196/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2117 - dice_coef: 0.6310 - val_loss: 0.1988 - val_dice_coef: 0.5980
# Epoch 197/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1554 - dice_coef: 0.6638 - val_loss: 0.1784 - val_dice_coef: 0.5697
# Epoch 198/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2079 - dice_coef: 0.6124 - val_loss: 0.1922 - val_dice_coef: 0.5663
# Epoch 199/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1828 - dice_coef: 0.6214 - val_loss: 0.1815 - val_dice_coef: 0.5718
# Epoch 200/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1985 - dice_coef: 0.6032 - val_loss: 0.1848 - val_dice_coef: 0.5881
# Epoch 201/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1920 - dice_coef: 0.6096 - val_loss: 0.1820 - val_dice_coef: 0.5932
# Epoch 202/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1888 - dice_coef: 0.6110 - val_loss: 0.1726 - val_dice_coef: 0.5880
# Epoch 203/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.1709 - dice_coef: 0.6371 - val_loss: 0.1732 - val_dice_coef: 0.5705
# Epoch 204/300
# 20/20 [==============================] - 32s 2s/step - loss: 0.1999 - dice_coef: 0.6118 - val_loss: 0.1931 - val_dice_coef: 0.5974
# Epoch 205/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.1754 - dice_coef: 0.6338 - val_loss: 0.1786 - val_dice_coef: 0.5810
# Epoch 206/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1490 - dice_coef: 0.6739 - val_loss: 0.1819 - val_dice_coef: 0.6171
# Epoch 207/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.2103 - dice_coef: 0.6218 - val_loss: 0.1856 - val_dice_coef: 0.5458
# Epoch 208/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1994 - dice_coef: 0.6061 - val_loss: 0.1903 - val_dice_coef: 0.5750
# Epoch 209/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1660 - dice_coef: 0.6375 - val_loss: 0.1862 - val_dice_coef: 0.5606
# Epoch 210/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2069 - dice_coef: 0.6073 - val_loss: 0.1802 - val_dice_coef: 0.5726
# Epoch 211/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1729 - dice_coef: 0.6349 - val_loss: 0.1887 - val_dice_coef: 0.5685
# Epoch 212/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1759 - dice_coef: 0.6370 - val_loss: 0.1830 - val_dice_coef: 0.5825
# Epoch 213/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1865 - dice_coef: 0.6285 - val_loss: 0.1816 - val_dice_coef: 0.6070
# Epoch 214/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1697 - dice_coef: 0.6492 - val_loss: 0.1818 - val_dice_coef: 0.6063
# Epoch 215/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1897 - dice_coef: 0.6342 - val_loss: 0.1823 - val_dice_coef: 0.6121
# Epoch 216/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1633 - dice_coef: 0.6599 - val_loss: 0.1817 - val_dice_coef: 0.5883
# Epoch 217/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1724 - dice_coef: 0.6543 - val_loss: 0.1785 - val_dice_coef: 0.6028
# Epoch 218/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1835 - dice_coef: 0.6437 - val_loss: 0.1818 - val_dice_coef: 0.6061
# Epoch 219/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1754 - dice_coef: 0.6488 - val_loss: 0.1790 - val_dice_coef: 0.6036
# Epoch 220/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2096 - dice_coef: 0.6046 - val_loss: 0.1838 - val_dice_coef: 0.5799
# Epoch 221/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1709 - dice_coef: 0.6352 - val_loss: 0.1828 - val_dice_coef: 0.5713
# Epoch 222/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1501 - dice_coef: 0.6706 - val_loss: 0.1729 - val_dice_coef: 0.6048
# Epoch 223/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.1768 - dice_coef: 0.6597 - val_loss: 0.1772 - val_dice_coef: 0.6172
# Epoch 224/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1737 - dice_coef: 0.6603 - val_loss: 0.1840 - val_dice_coef: 0.6191
# Epoch 225/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1746 - dice_coef: 0.6546 - val_loss: 0.1819 - val_dice_coef: 0.6203
# Epoch 226/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1714 - dice_coef: 0.6574 - val_loss: 0.1764 - val_dice_coef: 0.6026
# Epoch 227/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1985 - dice_coef: 0.6272 - val_loss: 0.1827 - val_dice_coef: 0.5679
# Epoch 228/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1438 - dice_coef: 0.6792 - val_loss: 0.1789 - val_dice_coef: 0.5953
# Epoch 229/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2071 - dice_coef: 0.6271 - val_loss: 0.1790 - val_dice_coef: 0.5792
# Epoch 230/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1841 - dice_coef: 0.6341 - val_loss: 0.1957 - val_dice_coef: 0.5754
# Epoch 231/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1998 - dice_coef: 0.6068 - val_loss: 0.1807 - val_dice_coef: 0.5409
# Epoch 232/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1618 - dice_coef: 0.6457 - val_loss: 0.1749 - val_dice_coef: 0.5859
# Epoch 233/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2027 - dice_coef: 0.6147 - val_loss: 0.1858 - val_dice_coef: 0.5502
# Epoch 234/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1675 - dice_coef: 0.6473 - val_loss: 0.1774 - val_dice_coef: 0.5779
# Epoch 235/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1904 - dice_coef: 0.6284 - val_loss: 0.1825 - val_dice_coef: 0.5664
# Epoch 236/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2165 - dice_coef: 0.5904 - val_loss: 0.1895 - val_dice_coef: 0.5457
# Epoch 237/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1989 - dice_coef: 0.5920 - val_loss: 0.1866 - val_dice_coef: 0.5467
# Epoch 238/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1994 - dice_coef: 0.5905 - val_loss: 0.1880 - val_dice_coef: 0.5386
# Epoch 239/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1713 - dice_coef: 0.6241 - val_loss: 0.1746 - val_dice_coef: 0.5701
# Epoch 240/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1987 - dice_coef: 0.6073 - val_loss: 0.1789 - val_dice_coef: 0.5814
# Epoch 241/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1912 - dice_coef: 0.6104 - val_loss: 0.1875 - val_dice_coef: 0.5587
# Epoch 242/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1810 - dice_coef: 0.6227 - val_loss: 0.1833 - val_dice_coef: 0.5679
# Epoch 243/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2202 - dice_coef: 0.5793 - val_loss: 0.1872 - val_dice_coef: 0.5159
# Epoch 244/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2079 - dice_coef: 0.5734 - val_loss: 0.1886 - val_dice_coef: 0.5579
# Epoch 245/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1794 - dice_coef: 0.6047 - val_loss: 0.1841 - val_dice_coef: 0.5756
# Epoch 246/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1988 - dice_coef: 0.5972 - val_loss: 0.1833 - val_dice_coef: 0.5598
# Epoch 247/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1922 - dice_coef: 0.6042 - val_loss: 0.1823 - val_dice_coef: 0.5686
# Epoch 248/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1714 - dice_coef: 0.6329 - val_loss: 0.1823 - val_dice_coef: 0.5686
# Epoch 249/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1919 - dice_coef: 0.6184 - val_loss: 0.1906 - val_dice_coef: 0.5754
# Epoch 250/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2065 - dice_coef: 0.5972 - val_loss: 0.1800 - val_dice_coef: 0.5805
# Epoch 251/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1775 - dice_coef: 0.6198 - val_loss: 0.1810 - val_dice_coef: 0.5702
# Epoch 252/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1741 - dice_coef: 0.6333 - val_loss: 0.1790 - val_dice_coef: 0.5663
# Epoch 253/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1912 - dice_coef: 0.6234 - val_loss: 0.1830 - val_dice_coef: 0.5890
# Epoch 254/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1642 - dice_coef: 0.6516 - val_loss: 0.1839 - val_dice_coef: 0.6082
# Epoch 255/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2029 - dice_coef: 0.6153 - val_loss: 0.1858 - val_dice_coef: 0.5838
# Epoch 256/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1758 - dice_coef: 0.6347 - val_loss: 0.1872 - val_dice_coef: 0.5796
# Epoch 257/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1771 - dice_coef: 0.6358 - val_loss: 0.1764 - val_dice_coef: 0.5885
# Epoch 258/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1848 - dice_coef: 0.6291 - val_loss: 0.1734 - val_dice_coef: 0.5779
# Epoch 259/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1916 - dice_coef: 0.6221 - val_loss: 0.1906 - val_dice_coef: 0.5817
# Epoch 260/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1964 - dice_coef: 0.6120 - val_loss: 0.1869 - val_dice_coef: 0.5591
# Epoch 261/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1639 - dice_coef: 0.6432 - val_loss: 0.1791 - val_dice_coef: 0.5491
# Epoch 262/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2044 - dice_coef: 0.6082 - val_loss: 0.1799 - val_dice_coef: 0.5742
# Epoch 263/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1749 - dice_coef: 0.6339 - val_loss: 0.1790 - val_dice_coef: 0.5815
# Epoch 264/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1751 - dice_coef: 0.6405 - val_loss: 0.1771 - val_dice_coef: 0.5945
# Epoch 265/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2068 - dice_coef: 0.6072 - val_loss: 0.1880 - val_dice_coef: 0.5634
# Epoch 266/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1728 - dice_coef: 0.6343 - val_loss: 0.1772 - val_dice_coef: 0.5848
# Epoch 267/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1921 - dice_coef: 0.6168 - val_loss: 0.1831 - val_dice_coef: 0.5679
# Epoch 268/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1572 - dice_coef: 0.6575 - val_loss: 0.1753 - val_dice_coef: 0.5948
# Epoch 269/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1784 - dice_coef: 0.6476 - val_loss: 0.1838 - val_dice_coef: 0.5765
# Epoch 270/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1650 - dice_coef: 0.6650 - val_loss: 0.1765 - val_dice_coef: 0.5938
# Epoch 271/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1914 - dice_coef: 0.6389 - val_loss: 0.1834 - val_dice_coef: 0.5728
# Epoch 272/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1348 - dice_coef: 0.6943 - val_loss: 0.1785 - val_dice_coef: 0.6107
# Epoch 273/300
# 20/20 [==============================] - 32s 2s/step - loss: 0.2040 - dice_coef: 0.6336 - val_loss: 0.1935 - val_dice_coef: 0.6096
# Epoch 274/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1543 - dice_coef: 0.6746 - val_loss: 0.1809 - val_dice_coef: 0.6094
# Epoch 275/300
# 20/20 [==============================] - 32s 2s/step - loss: 0.1838 - dice_coef: 0.6460 - val_loss: 0.1831 - val_dice_coef: 0.6089
# Epoch 276/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1857 - dice_coef: 0.6391 - val_loss: 0.1854 - val_dice_coef: 0.5661
# Epoch 277/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1869 - dice_coef: 0.6340 - val_loss: 0.1796 - val_dice_coef: 0.5831
# Epoch 278/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1931 - dice_coef: 0.6204 - val_loss: 0.1863 - val_dice_coef: 0.6015
# Epoch 279/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.1679 - dice_coef: 0.6433 - val_loss: 0.1823 - val_dice_coef: 0.5672
# Epoch 280/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2025 - dice_coef: 0.6081 - val_loss: 0.1869 - val_dice_coef: 0.5707
# Epoch 281/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1817 - dice_coef: 0.6270 - val_loss: 0.1801 - val_dice_coef: 0.5860
# Epoch 282/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1614 - dice_coef: 0.6564 - val_loss: 0.1828 - val_dice_coef: 0.5782
# Epoch 283/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1407 - dice_coef: 0.6950 - val_loss: 0.1742 - val_dice_coef: 0.6013
# Epoch 284/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2144 - dice_coef: 0.6295 - val_loss: 0.1863 - val_dice_coef: 0.5912
# Epoch 285/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1738 - dice_coef: 0.6456 - val_loss: 0.1811 - val_dice_coef: 0.5617
# Epoch 286/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.1692 - dice_coef: 0.6510 - val_loss: 0.1882 - val_dice_coef: 0.5634
# Epoch 287/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1852 - dice_coef: 0.6398 - val_loss: 0.1792 - val_dice_coef: 0.5772
# Epoch 288/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1720 - dice_coef: 0.6492 - val_loss: 0.1871 - val_dice_coef: 0.5837
# Epoch 289/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.2040 - dice_coef: 0.6144 - val_loss: 0.1775 - val_dice_coef: 0.5710
# Epoch 290/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1918 - dice_coef: 0.6152 - val_loss: 0.1899 - val_dice_coef: 0.5741
# Epoch 291/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1945 - dice_coef: 0.6098 - val_loss: 0.1858 - val_dice_coef: 0.5279
# Epoch 292/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1851 - dice_coef: 0.6160 - val_loss: 0.1837 - val_dice_coef: 0.5701
# Epoch 293/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1653 - dice_coef: 0.6455 - val_loss: 0.1778 - val_dice_coef: 0.5792
# Epoch 294/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1792 - dice_coef: 0.6417 - val_loss: 0.1846 - val_dice_coef: 0.5695
# Epoch 295/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1858 - dice_coef: 0.6369 - val_loss: 0.1840 - val_dice_coef: 0.6022
# Epoch 296/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1921 - dice_coef: 0.6209 - val_loss: 0.1840 - val_dice_coef: 0.5677
# Epoch 297/300
# 20/20 [==============================] - 30s 2s/step - loss: 0.1912 - dice_coef: 0.6170 - val_loss: 0.1844 - val_dice_coef: 0.5346
# Epoch 298/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.2084 - dice_coef: 0.5937 - val_loss: 0.1832 - val_dice_coef: 0.5639
# Epoch 299/300
# 20/20 [==============================] - 30s 1s/step - loss: 0.1708 - dice_coef: 0.6302 - val_loss: 0.1761 - val_dice_coef: 0.5815
# Epoch 300/300
# 20/20 [==============================] - 31s 2s/step - loss: 0.1819 - dice_coef: 0.6257 - val_loss: 0.1745 - val_dice_coef: 0.5862

# %%
print("Saving model...\n")   
model.save(final_weights_path)
# Out:
# Saving model...

# %% [markdown]
# ## Predict and Compute Uncertainty Map

# %%
def predict(data, model):
    """
    Data prediction for a given model
    :param data: input data to predict.
    :param model: unet model.
    :return: predictions.
    """
    return model.predict(data, verbose=0)

def compute_dice_coef(y_true, y_pred):
    """
    Computes the Dice-Coefficient of a prediction given its ground truth.
    :param y_true: Ground truth.
    :param y_pred: Prediction.
    :return: Dice-Coefficient value.
    """
    smooth = 1.  # smoothing value to deal zero denominators.
    y_true_f = y_true.reshape([1, img_rows * img_cols])
    y_pred_f = y_pred.reshape([1, img_rows * img_cols])
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

def compute_uncertain(sample, prediction, model):
    """
    Computes uncertainty map for a given sample and its prediction for a given model, based on the
    number of step predictions defined in constants file.
    :param sample: input sample.
    :param prediction: input sample prediction.
    :param model: unet model with Dropout layers.
    :return: overall uncertainty (not map) .
    """
    X = np.zeros([1, img_rows, img_cols])

    for t in range(nb_step_predictions):
        prediction = model.predict(sample, verbose=0).reshape([1, img_rows, img_cols])
        X = np.concatenate((X, prediction))

    X = np.delete(X, [0], 0)

    if (apply_edt):
        # apply distance transform normalization.
        var = np.var(X, axis=0)
        transform = range_transform(edt(prediction))
        return np.sum(var * transform)

    else:
        return np.sum(np.var(X, axis=0))

def compute_uncertain_map(sample, prediction, model):
    """
    Computes uncertainty map for a given sample and its prediction for a given model, based on the
    number of step predictions defined in constants file.
    :param sample: input sample.
    :param prediction: input sample prediction.
    :param model: unet model with Dropout layers.
    :return: uncertainty map.
    """
    X = np.zeros([1, img_rows, img_cols])

    for t in range(nb_step_predictions):
        prediction = model.predict(sample, verbose=0).reshape([1, img_rows, img_cols])
        X = np.concatenate((X, prediction))

    X = np.delete(X, [0], 0)

    if (apply_edt):
        # apply distance transform normalization.
        var = np.var(X, axis=0)
        transform = range_transform(edt(prediction))
        return var * transform

    else:
        return np.var(X, axis=0)

# %%
# Predictions

print("Computing log predictions ...\n")
predictions = predict(X_test, model)
print(len(predictions))
sample_prediction = cv2.threshold(predictions[0], 0.5, 1, cv2.THRESH_BINARY)[1].astype('uint8')
sample_prediction.shape
# Out:
# Computing log predictions ...
#
# 2
# (1, 512, 512)

# %%
plt.hist(predictions[0].flatten())
plt.title("Prediction histogram")
plt.show()
plt.hist(y_test[0].flatten())
plt.title("Mask histogram")
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.subplot(221)
plt.imshow(cv2.threshold(predictions[0][0, :, :], 0.2, 1, cv2.THRESH_BINARY)[1])
plt.title("Prediction sample 1")
plt.subplot(222)
plt.imshow(cv2.threshold(predictions[0][0, :, :], 0.4, 1, cv2.THRESH_BINARY)[1])
plt.title("Uncertainty map sample 1")
plt.subplot(223)
plt.imshow(cv2.threshold(predictions[0][0, :, :], 0.5, 1, cv2.THRESH_BINARY)[1])
plt.title("Sample 1")
plt.subplot(224)
plt.imshow(cv2.threshold(predictions[0][0, :, :], 0.6, 1, cv2.THRESH_BINARY)[1])
plt.title("Ground Truth sample 1")
plt.tight_layout()
plt.show()

# %%
# uncertainty computation

weights = final_weights_path
modelUncertain = unet_full_bn(dropout = True)
modelUncertain.load_weights(weights)

uncertain_map = []

print("Computing log predictions ...\n")
predictions = predict(X_test, model)

for i in range(len(X_test)):
    sample = X_test[i].reshape([1, 1, img_rows, img_cols])
    sample_prediction = cv2.threshold(predictions[i], 0.99, 1, cv2.THRESH_BINARY)[1].astype('uint8')
    uncertain_map_i = compute_uncertain_map(sample, sample_prediction, modelUncertain)
    uncertain_map.append(uncertain_map_i)
    
    
uncertain_map_array = np.asarray(uncertain_map)
print(uncertain_map_array.shape)
print("Done")
# Out:
# Computing log predictions ...
#
# (2, 512, 512)
# Done

# %%
# Plot predictions and uncertainty map for 2 samples 

plt.figure(figsize=(20,10))
plt.subplot(221)
plt.imshow(predictions[0][0,:,:])
plt.title("Prediction sample 1")
plt.subplot(222)
plt.imshow(uncertain_map_array[0])
plt.title("Uncertainty map sample 1")
plt.subplot(223)
plt.imshow(X_test[0][0,:,:])
plt.title("Sample 1")
plt.subplot(224)
plt.imshow(y_test[0][0,:,:])
plt.title("Ground Truth sample 1")
plt.tight_layout()
plt.show()

# %%
X = np.load(path_mask_train)[0]
X.shape
plt.imshow(X[0, :, :], cmap = 'gray')
plt.show()
X

# %%
np.min(X)
